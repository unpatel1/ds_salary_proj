# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                    Company Name         Location  \
# 0                      Tecolote Research\r\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\r\n3.4    Linthicum, MD
# 2                                KnowBe4\r\n4.8   Clearwater, FL
# 3                                   PNNL\r\n3.8     Richland, WA
# 4                     Affinity Solutions\r\n2.9     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  ...  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private  ...
# 1   Baltimore, MD        10000+ employees     1984  Other Organization  ...
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private  ...
# 3    Richland, WA  1001 to 5000 employees     1965          Government  ...
# 4    New York, NY     51 to 200 employees     1998   Company - Private  ...
#
#   avg_salary                               company_text job_state same_state  \
# 0       72.0                      Tecolote Research\r\n        NM          0
# 1       87.5  University of Maryland Medical System\r\n        MD          0
# 2       85.0                                KnowBe4\r\n        FL          1
# 3       76.5                                   PNNL\r\n        WA          1
# 4      114.5                     Affinity Solutions\r\n        NY          1
#
#    age  python_yn  R_yn  spark  aws excel
# 0   49          1     0      0    0     1
# 1   38          1     0      0    0     0
# 2   12          1     0      1    0     1
# 3   57          1     0      0    0     0
# 4   24          1     0      0    0     1
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if ('sr' in title.lower() or 'senior' in title.lower() or 'sr.' in title.lower() 
                              or 'lead' in title.lower() or 'principal' in title.lower()):
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'
		
## Job title and seniority 
		
##  Fix state Los Angeles 

##  Job description length 

##  Competitor count

## hourly wage to annual 

#remove new line from job title

# %%
df['Job Title'].unique()
# Out:
# array(['Data Scientist', 'Healthcare Data Scientist',
#        'Research Scientist', 'Staff Data Scientist - Technology',
#        'Data Analyst', 'Data Engineer I', 'Scientist I/II, Biology',
#        'Customer Data Scientist',
#        'Data Scientist - Health Data Analytics',
#        'Senior Data Scientist / Machine Learning',
#        'Data Scientist - Quantitative', 'Digital Health Data Scientist',
#        'Associate Data Analyst', 'Clinical Data Scientist',
#        'Data Scientist / Machine Learning Expert', 'Web Data Analyst',
#        'Senior Data Scientist', 'Data Engineer',
#        'Data Scientist - Algorithms & Inference', 'Scientist',
#        'Lead Data Scientist', 'Spectral Scientist/Engineer',
#        'College Hire - Data Scientist - Open to December 2019 Graduates',
#        'Data Scientist, Office of Data Science', 'Data Science Analyst',
#        'Senior Risk Data Scientist',
#        'Data Scientist in Artificial Intelligence Early Career',
#        'Data Scientist - Research', 'R&D Data Analysis Scientist',
#        'Analytics Consultant', 'Director, Data Science',
#        'Data Scientist SR', 'R&D Sr Data Scientist',
#        'Customer Data Scientist/Sales Engineer (Bay',
#        'Jr. Business Data Analyst', 'Data Management Specialist',
#        'E-Commerce Data Analyst', 'Sr. Scientist II',
#        'Insurance Data Scientist', 'Data Modeler',
#        'Data Analyst / Scientist', 'Data Scientist, Rice University',
#        'Financial Data Analyst', 'Senior Data Analyst',
#        'Ag Data Scientist', 'Data Scientist II', 'Senior Data Engineer',
#        'Project Scientist', 'Data Analytics Manager',
#        'Senior Machine Learning (ML) Engineer / Data Scientist - Cyber Security Analytics',
#        'Associate Scientist', 'Scientist 2, QC Viral Vector',
#        'Machine Learning Engineer', 'Data Scientist/ML Engineer',
#        'Sr. Data Scientist', 'Data Engineer 4 - Contract',
#        'Data Analyst - Asset Management',
#        'Senior Research Scientist - Embedded System Development for DevOps',
#        'Data Scientist - Bioinformatics',
#        'Customer Data Scientist/Sales Engineer',
#        'MongoDB Data Engineer II', 'Senior Data Scientist Statistics',
#        'Senior Spark Engineer (Data Science)',
#        'BI & Platform Analytics Manager',
#        'Sr. Data Scientist - Analytics, Personalized Healthcare (PHC)',
#        'Pricipal Scientist Molecular and cellular biologist',
#        'Data Scientist (Actuary, FSA or ASA)', 'Staff Data Scientist',
#        'Data Engineer 5 - Contract (Remote)',
#        'Senior Scientist - Neuroscience', 'Medical Lab Scientist',
#        'Risk and Analytics IT, Data Scientist',
#        'Scientist, Analytical Development', 'Analytics Manager',
#        'Digital Marketing & ECommerce Data Analyst',
#        'Sr. Scientist - Digital & Image Analysis/Computational Pathology',
#        'Principal Scientist - Immunologist',
#        'Principal Data Scientist with over 10 years experience',
#        'MED TECH/LAB SCIENTIST - LABORATORY',
#        'Sr. Scientist, Quantitative Translational Sciences',
#        'Sr. Data Scientist II', 'Excel / VBA / SQL Data Analyst',
#        'Machine Learning Research Scientist', 'VP, Data Science',
#        'Radar Data Analyst', 'PL Actuarial-Lead Data Scientist',
#        'PV Scientist', 'Senior Data & Machine Learning Scientist',
#        'Principal Data Scientist (Computational Chemistry)',
#        'Principal Scientist, Chemistry & Immunology',
#        'Software Engineer - Data Visualization',
#        'Scientist/Senior Scientist, Autoimmune',
#        'Staff Machine Learning Engineer',
#        'Principal Scientist, Hematology', 'Lead Data Engineer',
#        'Marketing Data Analyst', 'Medical Laboratory Scientist',
#        'R&D Specialist/ Food Scientist',
#        'Senior Research Scientist-Machine Learning',
#        'Analytics Manager - Data Mart',
#        'Sr. Data Engineer - Contract-to-Hire (Java)',
#        'MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB',
#        'Food Scientist - Developer',
#        'Staff Scientist-Downstream Process Development',
#        'Sr. Data Engineer',
#        'Senior Research Statistician- Data Scientist',
#        'Business Data Analyst, SQL',
#        'Medical Technologist / Clinical Laboratory Scientist',
#        'Associate Data Scientist/Computer Scientist',
#        'Business Intelligence Analyst / Developer',
#        'System and Data Analyst', 'Data & Analytics Consultant (NYC)',
#        'Big Data Engineer - Chicago - Future Opportunity',
#        'Survey Data Analyst', 'Lead Health Data Analyst - Front End',
#        'Junior Data Analyst', 'SQL Data Engineer',
#        'Sr. Data Scientist, Cyber-Security LT Contract',
#        'Insurance Financial Data Analyst', 'Data Engineer I - Azure',
#        'Information Security Data Analyst', 'Data Scientist, Senior',
#        'CONSULTANT– DATA ANALYTICS GROUP',
#        'Data Engineer, Data Engineering and Artifical Intelligence',
#        'Staff Scientist',
#        'Associate Scientist/Scientist, Process Analytical Technology - Small Molecule Analytical Chemistry',
#        'Sr. Data Analyst', 'Program/Data Analyst',
#        'Senior Data Scientist: Causal & Predictive analytics AI Innovation Lab',
#        'Principal Data Engineer, Data Platform & Insights',
#        'RESEARCH SCIENTIST - BIOLOGICAL SAFETY', 'Data Operations Lead',
#        'Big Data Engineer', 'Clinical Data Analyst',
#        'Computational Chemist/Data Scientist',
#        'Product Engineer – Data Science', 'Market Data Analyst',
#        'Staff Data Engineer', 'Associate Data Engineer',
#        'Staff BI and Data Engineer',
#        'Director - Data, Privacy and AI Governance',
#        'Scientist Manufacturing - Kentucky BioProcessing',
#        'Data Analytics Project Manager',
#        'Consultant - Analytics Consulting',
#        'Senior Scientist (Neuroscience)',
#        'Machine Learning Engineer - Regulatory',
#        'Scientist, Bacteriology',
#        'Associate Director, Platform and DevOps- Data Engineering and Aritifical Intelligence',
#        'Clinical Laboratory Scientist',
#        'Senior Data Scientist - R&D Oncology',
#        'Director II, Data Science - GRM Actuarial',
#        'Scientist, Molecular/Cellular Biologist',
#        'Scientist - Analytical Services',
#        'Associate Data Analyst- Graduate Development Program',
#        'Senior Insurance Data Scientist',
#        'Senior Data Science Systems Engineer',
#        'ENVIRONMENTAL ENGINEER/SCIENTIST',
#        'Senior Scientist - Regulatory Submissions',
#        'Scientist - Biomarker and Flow Cytometry',
#        'Revenue Analytics Manager',
#        'Associate Scientist, LC/MS Biologics',
#        'Sr. Scientist Method Development', 'IT - Data Engineer II',
#        'Research Scientist, Immunology - Cancer Biology',
#        'Project Scientist - Auton Lab, Robotics Institute',
#        'Enterprise Architect, Data',
#        'Senior Manager, Epidemiologic Data Scientist',
#        'Corporate Risk Data Analyst (SQL Based) - Milwaukee or',
#        'Marketing Data Analyst, May 2020 Undergrad',
#        'Data Modeler - Data Solutions Engineer',
#        'Associate Environmental Scientist - Wildlife Biologist',
#        'Associate, Data Science, Internal Audit',
#        'Sr Data Engineer (Sr BI Developer)',
#        'Senior LiDAR Data Scientist', 'Salesforce Analytics Consultant',
#        'Technology-Minded, Data Professional Opportunities',
#        'Managing Data Scientist/ML Engineer',
#        'Scientist, Pharmacometrics', 'Staff Scientist- Upstream PD',
#        'Scientist Manufacturing Pharma - Kentucky BioProcessing',
#        'Lead Big Data Engineer',
#        'Product Engineer – Spatial Data Science and Statistical Analysis',
#        'Sr Software Engineer (Data Scientist)',
#        'Sr. Data Engineer (ETL Developer)',
#        'Senior Data Scientist Artificial Intelligence',
#        'Analytics - Business Assurance Data Analyst',
#        'Associate Director/Director, Safety Scientist',
#        'Senior Scientist, Cell Pharmacology/Assay Development',
#        'Data Analyst Senior', 'Lead Data Engineer (Python)',
#        'Senior Data Scientist 4 Artificial Intelligence',
#        'Medical Lab Scientist - MLT',
#        'Senior Operations Data Analyst, Call Center Operations',
#        'Director II, Data Science - GRS Predictive Analytics',
#        'RESEARCH COMPUTER SCIENTIST - RESEARCH ENGINEER - SR. COMPUTER SCIENTIST - SOFTWARE DEVELOPMENT',
#        'Geospatial Software Developer and Data Scientist',
#        'Senior Scientist - Toxicologist - Product Integrity (Stewardship)',
#        'Systems Engineer II - Data Analyst',
#        'Senior Research Analytical Scientist-Non-Targeted Analysis',
#        'Director Data Science', 'Sr Data Analyst - IT',
#        'Associate Machine Learning Engineer / Data Scientist May 2020 Undergrad',
#        'Senior Scientist - Biostatistician',
#        'Principal Machine Learning Scientist',
#        'Data Analyst, Performance Partnership', 'Data Scientist Manager',
#        'Software Data Engineer - College',
#        'Senior Data Scientist - Algorithms',
#        'Senior Data Scientist Oncology', 'Principal Data Scientist',
#        'Data Scientist - Alpha Insights',
#        'Associate Principal Scientist, Pharmacogenomics',
#        'Data Scientist - Systems Engineering',
#        'Data Engineer - Consultant (Charlotte Based)',
#        'Data Analyst 1, full-time contract worker for up to 12 months',
#        'Scientist, Immuno-Oncology', 'Products Data Analyst II',
#        'Lead Data Analyst', 'Data Science Engineer - Mobile',
#        'Sr Expert Data Science, Advanced Visual Analytics (Associate level)',
#        'IT Associate Data Analyst', 'Business Data Analyst',
#        'Data Scientist - Sales',
#        'Principal, Data Science - Advanced Analytics',
#        'Data Science Project Manager',
#        'Sr Scientist, Immuno-Oncology - Oncology',
#        'Research Scientist – Security and Privacy',
#        'Data Science Manager', 'Data Analyst 2 (Missionary Department)',
#        'Supply Chain Data Analyst', 'Data Engineer - ETL',
#        'Data Modeler (Analytical Systems)',
#        'Data Scientist in Translational Medicine',
#        'Product Manager/Data Evangelist',
#        'Senior Data Scientist – Visualization, Novartis AI Innovation Lab',
#        'Senior Data Analyst/Scientist',
#        'Scientist – Cancer Discovery, Molecular Assay',
#        'Data Engineering Analyst', 'Manager of Data Science',
#        'Software Engineer (Data Scientist/Software Engineer) - SISW - MG',
#        'Associate Research Scientist I (Protein Expression and Production)',
#        'Director, Precision Medicine Clinical Biomarker Scientist',
#        'Senior Formulations Scientist II', 'Senior Quantitative Analyst',
#        'Research Scientist or Senior Research Scientist - Computer Vision',
#        'Data Analyst Chemist - Quality System Contractor',
#        'Research Scientist / Principal Research Scientist - Multiphysical Systems',
#        'Research Scientist, Machine Learning Department',
#        'Foundational Community Supports Data Analyst',
#        'Senior Health Data Analyst, Star Ratings',
#        'Principal Research Scientist/Team Lead, Medicinal Chemistry - Oncology',
#        'Senior Engineer, Data Management Engineering',
#        'Quality Control Scientist III- Analytical Development',
#        'Clinical Scientist, Clinical Development',
#        'Software Engineer Staff Scientist: Human Language Technologies',
#        'Manager, Safety Scientist, Medical Safety & Risk Management',
#        'Assistant Director/Director, Office of Data Science',
#        'Sr. Data Engineer | Big Data SaaS Pipeline',
#        'Scientist - CVRM Metabolism - in vivo pharmacology',
#        'Data Scientist (Warehouse Automation)', 'Jr. Data Scientist',
#        'Data Architect / Data Modeler',
#        'Associate Scientist / Sr. Associate Scientist, Antibody Discovery',
#        'Machine Learning Engineer (NLP)'], dtype=object)

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: job_simp, dtype: int64

# %%
df[df['job_simp'] == 'na'][:50]
# Out:
#                                              Job Title  \
# 8                                   Research Scientist
# 16                             Scientist I/II, Biology
# 43                                           Scientist
# 48                         Spectral Scientist/Engineer
# 69                         R&D Data Analysis Scientist
# 70                                Analytics Consultant
# 72                                           Scientist
# 77                                  Research Scientist
# 89                          Data Management Specialist
# 91                                    Sr. Scientist II
# 93                                        Data Modeler
# 95                                           Scientist
# 108                                 Research Scientist
# 125                                  Project Scientist
# 132                                Associate Scientist
# 133                       Scientist 2, QC Viral Vector
# 143  Senior Research Scientist - Embedded System De...
# 151               Senior Spark Engineer (Data Science)
# 157  Pricipal Scientist Molecular and cellular biol...
# 163                    Senior Scientist - Neuroscience
# 165                              Medical Lab Scientist
# 167                  Scientist, Analytical Development
# 172  Sr. Scientist - Digital & Image Analysis/Compu...
# 174                 Principal Scientist - Immunologist
# 177                MED TECH/LAB SCIENTIST - LABORATORY
# 178  Sr. Scientist, Quantitative Translational Scie...
# 182                                   VP, Data Science
# 186                                       PV Scientist
# 190        Principal Scientist, Chemistry & Immunology
# 191             Software Engineer - Data Visualization
# 192             Scientist/Senior Scientist, Autoimmune
# 194                    Principal Scientist, Hematology
# 197                       Medical Laboratory Scientist
# 198                     R&D Specialist/ Food Scientist
# 202          MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB
# 203                         Food Scientist - Developer
# 204     Staff Scientist-Downstream Process Development
# 210  Medical Technologist / Clinical Laboratory Sci...
# 223  Pricipal Scientist Molecular and cellular biol...
# 233                  Data & Analytics Consultant (NYC)
# 234                    Senior Scientist - Neuroscience
# 245                                 Research Scientist
# 246                              Medical Lab Scientist
# 252                  Scientist, Analytical Development
# 259  Sr. Scientist - Digital & Image Analysis/Compu...
# 261                 Principal Scientist - Immunologist
# 270  Sr. Scientist, Quantitative Translational Scie...
# 271                MED TECH/LAB SCIENTIST - LABORATORY
# 284                                   VP, Data Science
# 286                   CONSULTANT– DATA ANALYTICS GROUP
#
#                       Salary Estimate  \
# 8          $38K-$84K (Glassdoor est.)
# 16        $67K-$137K (Glassdoor est.)
# 43        $52K-$113K (Glassdoor est.)
# 48        $56K-$117K (Glassdoor est.)
# 69        $65K-$130K (Glassdoor est.)
# 70         $52K-$81K (Glassdoor est.)
# 72        $50K-$102K (Glassdoor est.)
# 77        $57K-$118K (Glassdoor est.)
# 89         $31K-$65K (Glassdoor est.)
# 91       $117K-$231K (Glassdoor est.)
# 93        $79K-$134K (Glassdoor est.)
# 95        $55K-$116K (Glassdoor est.)
# 108        $38K-$85K (Glassdoor est.)
# 125        $29K-$50K (Glassdoor est.)
# 132       $51K-$112K (Glassdoor est.)
# 133      $113K-$223K (Glassdoor est.)
# 143       $81K-$167K (Glassdoor est.)
# 151       $65K-$148K (Glassdoor est.)
# 157       $52K-$101K (Glassdoor est.)
# 163      $100K-$190K (Glassdoor est.)
# 165  $17-$24 Per Hour(Glassdoor est.)
# 167        $42K-$82K (Glassdoor est.)
# 172      $105K-$198K (Glassdoor est.)
# 174       $98K-$182K (Glassdoor est.)
# 177  $21-$34 Per Hour(Glassdoor est.)
# 178      $117K-$206K (Glassdoor est.)
# 182       $83K-$166K (Glassdoor est.)
# 186       $60K-$123K (Glassdoor est.)
# 190       $54K-$115K (Glassdoor est.)
# 191       $60K-$127K (Glassdoor est.)
# 192       $90K-$179K (Glassdoor est.)
# 194       $54K-$115K (Glassdoor est.)
# 197  $18-$25 Per Hour(Glassdoor est.)
# 198        $39K-$66K (Glassdoor est.)
# 202  $21-$34 Per Hour(Glassdoor est.)
# 203        $40K-$68K (Glassdoor est.)
# 204       $49K-$113K (Glassdoor est.)
# 210  $15-$25 Per Hour(Glassdoor est.)
# 223       $52K-$101K (Glassdoor est.)
# 233       $91K-$138K (Glassdoor est.)
# 234      $100K-$190K (Glassdoor est.)
# 245        $33K-$72K (Glassdoor est.)
# 246  $17-$24 Per Hour(Glassdoor est.)
# 252        $42K-$82K (Glassdoor est.)
# 259      $105K-$198K (Glassdoor est.)
# 261       $98K-$182K (Glassdoor est.)
# 270      $117K-$206K (Glassdoor est.)
# 271  $21-$34 Per Hour(Glassdoor est.)
# 284       $83K-$166K (Glassdoor est.)
# 286        $37K-$68K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 8    SUMMARY\r\n\r\nThe Research Scientist I will b...     3.3
# 16   Scientist I/II, Biology\r\n\r\nCambridge, MA\r...     3.9
# 43   We are a global team of 6000 visionaries, doer...     3.4
# 48   Thank you for your interest in joining the Cen...     4.7
# 69   Applies developed level of subject matter know...     4.0
# 70   SpringML is seeking an Analytics Consultant to...     4.4
# 72   Scientist\r\nOrganization\r\n\r\n\r\nEurofins ...     2.7
# 77   Company Overview\r\n\r\nImagine if we could ma...     1.9
# 89   Location: Huntsville, AL\r\n\r\nClearance: Sec...     4.5
# 91   Sr. Scientist II\r\nLocation\r\n\r\n\r\nSan Fr...     3.5
# 93   The database modeler shall perform analysis of...     4.7
# 95   Type of Requisition:\r\n\r\nRegular\r\n\r\nCle...     3.4
# 108  Research Scientist\r\nLocation\r\n\r\n\r\nNebr...     2.9
# 125  Project Scientist\r\n\r\nJob Details\r\nLevel\...     4.0
# 132  Requisition Number:\r\nVALA4950\r\n\r\nJob Tit...     2.9
# 133  BioMarin is the world leader in delivering the...     3.8
# 143  What We Do\r\n\r\nThe SEI helps advance softwa...     2.6
# 151  Company Description\r\n\r\nAt KSM Consulting, ...     4.4
# 157  Job Description\r\n\r\n\r\nOBJECTIVE:\r\nHelp ...     3.7
# 163  Sunovion Pharmaceuticals is looking for a Seni...     3.5
# 165  Overview\r\n\r\nAbout\r\n\r\n\r\nTower Health ...     3.6
# 167  Rubius Therapeutics is a clinical-stage biopha...     4.4
# 172  Job Description\r\n\r\n\r\nAre you looking for...     3.7
# 174  Job Description\r\n\r\n\r\nOBJECTIVE:\r\nMake ...     3.7
# 177  Evening: 3P-1130P or Night Shift 11P-730A\r\n\...     3.6
# 178  Job Description\r\n\r\n\r\nMillennium Pharmace...     3.7
# 182  Oversee a team of Data Scientists with overall...     3.2
# 186  SUMMARY:\r\nThe Pharmacovigilance Scientist su...     2.9
# 190  SUMMARY\r\n\r\nThe Principal Scientist will re...     3.3
# 191  Join ClearEdge and be a part of the team of me...     4.0
# 192  Rubius Therapeutics is a clinical-stage biopha...     4.4
# 194  SUMMARY\r\n\r\nThe Principal Scientist will re...     3.3
# 197  Description\r\nMedical Laboratory Scientist - ...     4.0
# 198  Responsibilities Include but may not be limite...     2.4
# 202  Day Shift: 7A-330P. Holidays and every other w...     3.6
# 203  Palermo Villa Inc. is interested in a high-ene...     3.3
# 204  ABL is seeking a Staff Scientist for the Downs...     2.7
# 210  The incumbent performs a broad range of labora...     3.4
# 223  Job Description\r\n\r\n\r\nOBJECTIVE:\r\nHelp ...     3.7
# 233  WHO WE LOOK FOR\r\n\r\nAn SEI Consultant is a ...     4.7
# 234  Sunovion Pharmaceuticals is looking for a Seni...     3.5
# 245  Job Title: Research Scientist Expertise in lan...     3.8
# 246  Overview\r\n\r\nAbout\r\n\r\n\r\nTower Health ...     3.6
# 252  Rubius Therapeutics is a clinical-stage biopha...     4.4
# 259  Job Description\r\n\r\n\r\nAre you looking for...     3.7
# 261  Job Description\r\n\r\n\r\nOBJECTIVE:\r\nMake ...     3.7
# 270  Job Description\r\n\r\n\r\nMillennium Pharmace...     3.7
# 271  Evening: 3P-1130P or Night Shift 11P-730A\r\n\...     3.6
# 284  Oversee a team of Data Scientists with overall...     3.2
# 286  CONSULTANT– DATA ANALYTICS GROUP\r\n\r\n\r\nOp...     4.2
#
#                                           Company Name  \
# 8                     Rochester Regional Health\r\n3.3
# 16                          Blueprint Medicines\r\n3.9
# 43                       Edgewell Personal Care\r\n3.4
# 48                                     Centauri\r\n4.7
# 69                                      HP Inc.\r\n4.0
# 70                                     SpringML\r\n4.4
# 72                             EAG Laboratories\r\n2.7
# 77                               GNS Healthcare\r\n1.9
# 89                               NMR Consulting\r\n4.5
# 91                          Nektar Therapeutics\r\n3.5
# 93                                  IT Concepts\r\n4.7
# 95      General Dynamics Information Technology\r\n3.4
# 108                          Boys Town Hospital\r\n2.9
# 125                     Alliance Source Testing\r\n4.0
# 132                                  Pharmavite\r\n2.9
# 133                     BioMarin Pharmaceutical\r\n3.8
# 143              Software Engineering Institute\r\n2.6
# 151                              KSM Consulting\r\n4.4
# 157                      Takeda Pharmaceuticals\r\n3.7
# 163                                    Sunovion\r\n3.5
# 165                                Tower Health\r\n3.6
# 167                         Rubius Therapeutics\r\n4.4
# 172                      Takeda Pharmaceuticals\r\n3.7
# 174                      Takeda Pharmaceuticals\r\n3.7
# 177                            Beebe Healthcare\r\n3.6
# 178                      Takeda Pharmaceuticals\r\n3.7
# 182                                    PennyMac\r\n3.2
# 186                Karyopharm Therapeutics Inc.\r\n2.9
# 190                   Rochester Regional Health\r\n3.3
# 191                                   ClearEdge\r\n4.0
# 192                         Rubius Therapeutics\r\n4.4
# 194                   Rochester Regional Health\r\n3.3
# 197               Texas Health Huguley Hospital\r\n4.0
# 198                        Teasdale Latin Foods\r\n2.4
# 202                            Beebe Healthcare\r\n3.6
# 203                             Palermo's Pizza\r\n3.3
# 204            Advanced BioScience Laboratories\r\n2.7
# 210  Veterans Affairs, Veterans Health Administrati...
# 223                      Takeda Pharmaceuticals\r\n3.7
# 233                      Systems Evolution Inc.\r\n4.7
# 234                                    Sunovion\r\n3.5
# 245                                   Boys Town\r\n3.8
# 246                                Tower Health\r\n3.6
# 252                         Rubius Therapeutics\r\n4.4
# 259                      Takeda Pharmaceuticals\r\n3.7
# 261                      Takeda Pharmaceuticals\r\n3.7
# 270                      Takeda Pharmaceuticals\r\n3.7
# 271                            Beebe Healthcare\r\n3.6
# 284                                    PennyMac\r\n3.2
# 286                            Opinion Dynamics\r\n4.2
#
#                    Location            Headquarters                     Size  \
# 8             Rochester, NY           Rochester, NY         10000+ employees
# 16            Cambridge, MA           Cambridge, MA      51 to 200 employees
# 43            Allendale, NJ             Shelton, CT  5001 to 10000 employees
# 48          Beavercreek, OH           Chantilly, VA    501 to 1000 employees
# 69            Vancouver, WA           Palo Alto, CA         10000+ employees
# 70         Indianapolis, IN          Pleasanton, CA        1 to 50 employees
# 72     Maryland Heights, MO           San Diego, CA    501 to 1000 employees
# 77            Cambridge, MA           Cambridge, MA      51 to 200 employees
# 89           Huntsville, AL           Chantilly, VA      51 to 200 employees
# 91        San Francisco, CA       San Francisco, CA     201 to 500 employees
# 93             Landover, MD              Vienna, VA      51 to 200 employees
# 95             Suitland, MD             Fairfax, VA         10000+ employees
# 108               Omaha, NE               Omaha, NE   1001 to 5000 employees
# 125           Alabaster, AL             Decatur, AL      51 to 200 employees
# 132            Valencia, CA          West Hills, CA   1001 to 5000 employees
# 133              Novato, CA          San Rafael, CA   1001 to 5000 employees
# 143          Pittsburgh, PA          Pittsburgh, PA    501 to 1000 employees
# 151        Indianapolis, IN        Indianapolis, IN      51 to 200 employees
# 157              Boston, MA            OSAKA, Japan         10000+ employees
# 163         Marlborough, MA         Marlborough, MA   1001 to 5000 employees
# 165        West Reading, PA             Reading, PA  5001 to 10000 employees
# 167           Cambridge, MA           Cambridge, MA     201 to 500 employees
# 172           San Diego, CA            OSAKA, Japan         10000+ employees
# 174              Boston, MA            OSAKA, Japan         10000+ employees
# 177               Lewes, DE               Lewes, DE   1001 to 5000 employees
# 178              Boston, MA            OSAKA, Japan         10000+ employees
# 182             Phoenix, AZ    Westlake Village, CA   1001 to 5000 employees
# 186              Newton, MA              Newton, MA     201 to 500 employees
# 190           Rochester, NY           Rochester, NY         10000+ employees
# 191  Annapolis Junction, MD  Annapolis Junction, MD      51 to 200 employees
# 192           Cambridge, MA           Cambridge, MA     201 to 500 employees
# 194           Rochester, NY           Rochester, NY         10000+ employees
# 197            Burleson, TX           Arlington, TX   1001 to 5000 employees
# 198           Hoopeston, IL        Flower Mound, TX    501 to 1000 employees
# 202           Millville, DE               Lewes, DE   1001 to 5000 employees
# 203           Milwaukee, WI           Milwaukee, WI    501 to 1000 employees
# 204           Rockville, MD           Rockville, MD     201 to 500 employees
# 210         New Orleans, LA          Washington, DC         10000+ employees
# 223              Boston, MA            OSAKA, Japan         10000+ employees
# 233            New York, NY          Cincinnati, OH     201 to 500 employees
# 234         Marlborough, MA         Marlborough, MA   1001 to 5000 employees
# 245               Omaha, NE               Omaha, NE   1001 to 5000 employees
# 246        West Reading, PA             Reading, PA  5001 to 10000 employees
# 252           Cambridge, MA           Cambridge, MA     201 to 500 employees
# 259           San Diego, CA            OSAKA, Japan         10000+ employees
# 261              Boston, MA            OSAKA, Japan         10000+ employees
# 270              Boston, MA            OSAKA, Japan         10000+ employees
# 271               Lewes, DE               Lewes, DE   1001 to 5000 employees
# 284             Phoenix, AZ    Westlake Village, CA   1001 to 5000 employees
# 286           San Diego, CA             Waltham, MA      51 to 200 employees
#
#      Founded               Type of ownership  ...  \
# 8       2014                        Hospital  ...
# 16      2011                Company - Public  ...
# 43      2015                Company - Public  ...
# 48      1999               Company - Private  ...
# 69      1939                Company - Public  ...
# 70      2015               Company - Private  ...
# 72      1978  Subsidiary or Business Segment  ...
# 77      2000               Company - Private  ...
# 89      1996               Company - Private  ...
# 91      1990                Company - Public  ...
# 93      2003               Company - Private  ...
# 95      1996  Subsidiary or Business Segment  ...
# 108     1977                        Hospital  ...
# 125     2000                         Unknown  ...
# 132     1971               Company - Private  ...
# 133     1997                Company - Public  ...
# 143     1984            College / University  ...
# 151     2008               Company - Private  ...
# 157     1781                Company - Public  ...
# 163     2010               Company - Private  ...
# 165     2017          Nonprofit Organization  ...
# 167     2013                Company - Public  ...
# 172     1781                Company - Public  ...
# 174     1781                Company - Public  ...
# 177     1935          Nonprofit Organization  ...
# 178     1781                Company - Public  ...
# 182     2008                Company - Public  ...
# 186       -1                Company - Public  ...
# 190     2014                        Hospital  ...
# 191     2002               Company - Private  ...
# 192     2013                Company - Public  ...
# 194     2014                        Hospital  ...
# 197     1977                        Hospital  ...
# 198       -1               Company - Private  ...
# 202     1935          Nonprofit Organization  ...
# 203     1964               Company - Private  ...
# 204     1961               Company - Private  ...
# 210     1930                      Government  ...
# 223     1781                Company - Public  ...
# 233     1992               Company - Private  ...
# 234     2010               Company - Private  ...
# 245     1917          Nonprofit Organization  ...
# 246     2017          Nonprofit Organization  ...
# 252     2013                Company - Public  ...
# 259     1781                Company - Public  ...
# 261     1781                Company - Public  ...
# 270     1781                Company - Public  ...
# 271     1935          Nonprofit Organization  ...
# 284     2008                Company - Public  ...
# 286     1987               Company - Private  ...
#
#                                           company_text job_state same_state  \
# 8                        Rochester Regional Health\r\n        NY          1
# 16                             Blueprint Medicines\r\n        MA          1
# 43                          Edgewell Personal Care\r\n        NJ          0
# 48                                        Centauri\r\n        OH          0
# 69                                         HP Inc.\r\n        WA          0
# 70                                        SpringML\r\n        IN          0
# 72                                EAG Laboratories\r\n        MO          0
# 77                                  GNS Healthcare\r\n        MA          1
# 89                                  NMR Consulting\r\n        AL          0
# 91                             Nektar Therapeutics\r\n        CA          1
# 93                                     IT Concepts\r\n        MD          0
# 95         General Dynamics Information Technology\r\n        MD          0
# 108                             Boys Town Hospital\r\n        NE          1
# 125                        Alliance Source Testing\r\n        AL          0
# 132                                     Pharmavite\r\n        CA          0
# 133                        BioMarin Pharmaceutical\r\n        CA          0
# 143                 Software Engineering Institute\r\n        PA          1
# 151                                 KSM Consulting\r\n        IN          1
# 157                         Takeda Pharmaceuticals\r\n        MA          0
# 163                                       Sunovion\r\n        MA          1
# 165                                   Tower Health\r\n        PA          0
# 167                            Rubius Therapeutics\r\n        MA          1
# 172                         Takeda Pharmaceuticals\r\n        CA          0
# 174                         Takeda Pharmaceuticals\r\n        MA          0
# 177                               Beebe Healthcare\r\n        DE          1
# 178                         Takeda Pharmaceuticals\r\n        MA          0
# 182                                       PennyMac\r\n        AZ          0
# 186                   Karyopharm Therapeutics Inc.\r\n        MA          1
# 190                      Rochester Regional Health\r\n        NY          1
# 191                                      ClearEdge\r\n        MD          1
# 192                            Rubius Therapeutics\r\n        MA          1
# 194                      Rochester Regional Health\r\n        NY          1
# 197                  Texas Health Huguley Hospital\r\n        TX          0
# 198                           Teasdale Latin Foods\r\n        IL          0
# 202                               Beebe Healthcare\r\n        DE          0
# 203                                Palermo's Pizza\r\n        WI          1
# 204               Advanced BioScience Laboratories\r\n        MD          1
# 210  Veterans Affairs, Veterans Health Administrati...        LA          0
# 223                         Takeda Pharmaceuticals\r\n        MA          0
# 233                         Systems Evolution Inc.\r\n        NY          0
# 234                                       Sunovion\r\n        MA          1
# 245                                      Boys Town\r\n        NE          1
# 246                                   Tower Health\r\n        PA          0
# 252                            Rubius Therapeutics\r\n        MA          1
# 259                         Takeda Pharmaceuticals\r\n        CA          0
# 261                         Takeda Pharmaceuticals\r\n        MA          0
# 270                         Takeda Pharmaceuticals\r\n        MA          0
# 271                               Beebe Healthcare\r\n        DE          1
# 284                                       PennyMac\r\n        AZ          0
# 286                               Opinion Dynamics\r\n        CA          0
#
#      age  python_yn  R_yn  spark  aws  excel job_simp
# 8      8          0     0      0    0      0       na
# 16    11          0     0      0    0      1       na
# 43     7          0     0      0    1      0       na
# 48    23          0     0      0    0      0       na
# 69    83          0     0      0    0      0       na
# 70     7          1     0      0    0      0       na
# 72    44          0     0      0    0      1       na
# 77    22          0     0      0    1      0       na
# 89    26          0     0      0    0      1       na
# 91    32          0     0      0    0      1       na
# 93    19          0     0      0    0      0       na
# 95    26          0     0      0    0      0       na
# 108   45          0     0      0    0      1       na
# 125   22          0     0      0    0      0       na
# 132   51          0     0      0    0      1       na
# 133   25          0     0      0    0      1       na
# 143   38          1     0      0    0      1       na
# 151   14          1     0      1    1      0       na
# 157  241          0     0      0    0      1       na
# 163   12          1     0      0    0      1       na
# 165    5          0     0      0    0      0       na
# 167    9          0     0      0    0      0       na
# 172  241          0     0      0    0      1       na
# 174  241          0     0      0    0      1       na
# 177   87          0     0      0    0      0       na
# 178  241          0     0      0    0      0       na
# 182   14          1     0      0    0      1       na
# 186   -1          0     0      0    0      1       na
# 190    8          0     0      0    0      0       na
# 191   20          0     0      0    0      1       na
# 192    9          0     0      0    0      0       na
# 194    8          0     0      0    0      0       na
# 197   45          0     0      0    1      0       na
# 198   -1          0     0      0    0      0       na
# 202   87          0     0      0    0      0       na
# 203   58          0     0      0    0      0       na
# 204   61          0     0      0    0      1       na
# 210   92          0     0      0    0      0       na
# 223  241          0     0      0    0      1       na
# 233   30          1     0      0    0      1       na
# 234   12          1     0      0    0      1       na
# 245  105          0     0      0    0      1       na
# 246    5          0     0      0    0      0       na
# 252    9          0     0      0    0      0       na
# 259  241          0     0      0    0      1       na
# 261  241          0     0      0    0      1       na
# 270  241          0     0      0    0      0       na
# 271   87          0     0      0    0      0       na
# 284   14          1     0      0    0      1       na
# 286   35          1     0      0    0      0       na
#
# [50 rows x 29 columns]

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniority, dtype: int64

# %%
df[df['seniority'] != 'na'][:50]
# Out:
#                                              Job Title  \
# 21            Senior Data Scientist / Machine Learning
# 38                               Senior Data Scientist
# 44                               Senior Data Scientist
# 46                                 Lead Data Scientist
# 60                               Senior Data Scientist
# 62                          Senior Risk Data Scientist
# 73                                   Data Scientist SR
# 75                               R&D Sr Data Scientist
# 81                           Jr. Business Data Analyst
# 91                                    Sr. Scientist II
# 99                                 Lead Data Scientist
# 103                              Senior Data Scientist
# 105                              Senior Data Scientist
# 107                                Senior Data Analyst
# 119                               Senior Data Engineer
# 128  Senior Machine Learning (ML) Engineer / Data S...
# 130                              Senior Data Scientist
# 140                                 Sr. Data Scientist
# 143  Senior Research Scientist - Embedded System De...
# 147                                Lead Data Scientist
# 149                   Senior Data Scientist Statistics
# 150                                Senior Data Analyst
# 151               Senior Spark Engineer (Data Science)
# 154                                Lead Data Scientist
# 155  Sr. Data Scientist - Analytics, Personalized H...
# 156                              Senior Data Scientist
# 160           Senior Data Scientist / Machine Learning
# 163                    Senior Scientist - Neuroscience
# 164                                Senior Data Analyst
# 168                              Senior Data Scientist
# 172  Sr. Scientist - Digital & Image Analysis/Compu...
# 173                                Senior Data Analyst
# 174                 Principal Scientist - Immunologist
# 175                              Senior Data Scientist
# 176  Principal Data Scientist with over 10 years ex...
# 178  Sr. Scientist, Quantitative Translational Scie...
# 179                              Sr. Data Scientist II
# 183                              Senior Data Scientist
# 185                   PL Actuarial-Lead Data Scientist
# 187           Senior Data & Machine Learning Scientist
# 188  Principal Data Scientist (Computational Chemis...
# 190        Principal Scientist, Chemistry & Immunology
# 192             Scientist/Senior Scientist, Autoimmune
# 194                    Principal Scientist, Hematology
# 195                                 Lead Data Engineer
# 199         Senior Research Scientist-Machine Learning
# 201        Sr. Data Engineer - Contract-to-Hire (Java)
# 205                                  Sr. Data Engineer
# 208       Senior Research Statistician- Data Scientist
# 212                                Senior Data Analyst
#
#                           Salary Estimate  \
# 21            $73K-$119K (Glassdoor est.)
# 38           $115K-$180K (Glassdoor est.)
# 44             $110K-$150K(Employer est.)
# 46           $158K-$211K (Glassdoor est.)
# 60            $82K-$132K (Glassdoor est.)
# 62           $107K-$172K (Glassdoor est.)
# 73            $85K-$139K (Glassdoor est.)
# 75            $99K-$157K (Glassdoor est.)
# 81             $37K-$76K (Glassdoor est.)
# 91           $117K-$231K (Glassdoor est.)
# 99           $102K-$164K (Glassdoor est.)
# 103            $200K-$275K(Employer est.)
# 105           $80K-$129K (Glassdoor est.)
# 107            $39K-$71K (Glassdoor est.)
# 119           $95K-$173K (Glassdoor est.)
# 128           $61K-$118K (Glassdoor est.)
# 130          $112K-$182K (Glassdoor est.)
# 140           $80K-$130K (Glassdoor est.)
# 143           $81K-$167K (Glassdoor est.)
# 147           $75K-$125K (Glassdoor est.)
# 149           $74K-$123K (Glassdoor est.)
# 150            $44K-$78K (Glassdoor est.)
# 151           $65K-$148K (Glassdoor est.)
# 154          $124K-$204K (Glassdoor est.)
# 155          $131K-$207K (Glassdoor est.)
# 156          $110K-$174K (Glassdoor est.)
# 160           $73K-$119K (Glassdoor est.)
# 163          $100K-$190K (Glassdoor est.)
# 164            $43K-$80K (Glassdoor est.)
# 168          $116K-$185K (Glassdoor est.)
# 172          $105K-$198K (Glassdoor est.)
# 173           $55K-$100K (Glassdoor est.)
# 174           $98K-$182K (Glassdoor est.)
# 175           $73K-$124K (Glassdoor est.)
# 176  Employer Provided Salary:$200K-$250K
# 178          $117K-$206K (Glassdoor est.)
# 179          $111K-$183K (Glassdoor est.)
# 183          $114K-$182K (Glassdoor est.)
# 185          $114K-$179K (Glassdoor est.)
# 187          $100K-$166K (Glassdoor est.)
# 188          $108K-$173K (Glassdoor est.)
# 190           $54K-$115K (Glassdoor est.)
# 192           $90K-$179K (Glassdoor est.)
# 194           $54K-$115K (Glassdoor est.)
# 195            $190K-$220K(Employer est.)
# 199           $81K-$167K (Glassdoor est.)
# 201           $69K-$127K (Glassdoor est.)
# 205           $75K-$140K (Glassdoor est.)
# 208           $76K-$125K (Glassdoor est.)
# 212            $44K-$78K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 21   IMMEDIATE NEED FOR A SENIOR DATA SCIENTIST / M...     3.9
# 38   Sartorius Stedim Data Analytics, a market lead...     3.5
# 44   Working for Equity Residential (EQR), a leadin...     4.3
# 46   As the world's leader in digital payments tech...     3.7
# 60   Overview\r\n\r\n\r\nEveryone wants to work wit...     4.4
# 62   About Bill.com\r\n\r\nBill.com is a leading pr...     3.8
# 73   Data Scientist, Senior, Charlottesville, VA\r\...     3.9
# 75   We are seeking an experienced and innovative D...     4.0
# 81   Hi there! We're WebFX, a full-service digital ...     4.7
# 91   Sr. Scientist II\r\nLocation\r\n\r\n\r\nSan Fr...     3.5
# 99   Position Title: Lead Data Scientist\r\n\r\nDep...     4.1
# 103  Who we want:\r\nAre you committed to using you...     4.2
# 105  We are AAM. We have the POWER to move the worl...     3.3
# 107  Integrate is a rapidly growing, venture-backed...     4.3
# 119  The mission of our data team at Red Ventures t...     3.2
# 128  As the world’s leader in digital payments tech...     3.7
# 130  Are you passionate about solving challenging p...     4.0
# 140  The position\r\n\r\nWere seeking an entreprene...     3.7
# 143  What We Do\r\n\r\nThe SEI helps advance softwa...     2.6
# 147  Position: Lead Data Scientist\r\n\r\nLocation:...     3.8
# 149  *Organization and Job ID**\r\nJob ID: 310566\r...     3.8
# 150  KnowBe4, Inc. is a high growth information sec...     4.8
# 151  Company Description\r\n\r\nAt KSM Consulting, ...     4.4
# 154  Job Description\r\n\r\nSince 1851, MassMutuals...     3.6
# 155  The Position\r\n\r\n\r\nPurpose\r\n\r\nAs a Se...     3.9
# 156  Senior Data Scientist\r\n\r\nMist, a Juniper C...     3.8
# 160  IMMEDIATE NEED FOR A SENIOR DATA SCIENTIST / M...     3.9
# 163  Sunovion Pharmaceuticals is looking for a Seni...     3.5
# 164  About the Role:\r\n\r\n\r\nThe Senior Speciali...     2.9
# 168  Location: San Francisco, CA- United States\r\n...     4.0
# 172  Job Description\r\n\r\n\r\nAre you looking for...     3.7
# 173  As a precaution and in compliance with applica...     2.8
# 174  Job Description\r\n\r\n\r\nOBJECTIVE:\r\nMake ...     3.7
# 175  The Senior Data Scientist independently develo...     3.3
# 176  Position Title: Principal Data Scientist\r\nLo...    -1.0
# 178  Job Description\r\n\r\n\r\nMillennium Pharmace...     3.7
# 179  Data Scientist\r\n\r\nBefore the dawn of every...     3.4
# 183  Data Scientist's at Zest AI use the power of m...     3.9
# 185  Monday, October 21, 2019\r\n\r\nOur PL Data Sc...     3.7
# 187  Passionate about precision medicine and advanc...     3.0
# 188  At Recursion, we combine experimental biology,...     4.7
# 190  SUMMARY\r\n\r\nThe Principal Scientist will re...     3.3
# 192  Rubius Therapeutics is a clinical-stage biopha...     4.4
# 194  SUMMARY\r\n\r\nThe Principal Scientist will re...     3.3
# 195  Credit Sesame is bringing cash and credit toge...     4.1
# 199  What We Do:\r\n\r\nAt the SEI Emerging Technol...     2.6
# 201  As we strive to make a better day for our gues...     3.0
# 205  Position Purpose\r\n\r\nAs a Senior Data Engin...     3.4
# 208  Acuity is seeking a Senior Research Statistici...     4.8
# 212  KnowBe4, Inc. is a high growth information sec...     4.8
#
#                                  Company Name                 Location  \
# 21                           Health IQ\r\n3.9               Dallas, TX
# 38                           Sartorius\r\n3.5              Fremont, CA
# 44                  Equity Residential\r\n4.3              Chicago, IL
# 46                           Visa Inc.\r\n3.7             Bellevue, WA
# 60         The David J. Joseph Company\r\n4.4           Cincinnati, OH
# 62                            Bill.com\r\n3.8            Palo Alto, CA
# 73                   The Buffalo Group\r\n3.9      Charlottesville, VA
# 75                             HP Inc.\r\n4.0            Vancouver, WA
# 81                           webfx.com\r\n4.7           Harrisburg, PA
# 91                 Nektar Therapeutics\r\n3.5        San Francisco, CA
# 99                             Redjack\r\n4.1        Silver Spring, MD
# 103                             Gallup\r\n4.2           Washington, DC
# 105      American Axle & Manufacturing\r\n3.3           Southfield, MI
# 107                          Integrate\r\n4.3              Phoenix, AZ
# 119                       Red Ventures\r\n3.2            Charlotte, NC
# 128                          Visa Inc.\r\n3.7              Ashburn, VA
# 130                            Novetta\r\n4.0              Herndon, VA
# 140             Evolve Vacation Rental\r\n3.7               Denver, CO
# 143     Software Engineering Institute\r\n2.6           Pittsburgh, PA
# 147                       PatientPoint\r\n3.8           Cincinnati, OH
# 149                               PNNL\r\n3.8             Richland, WA
# 150                            KnowBe4\r\n4.8           Clearwater, FL
# 151                     KSM Consulting\r\n4.4         Indianapolis, IN
# 154                         MassMutual\r\n3.6               Boston, MA
# 155                          Genentech\r\n3.9  South San Francisco, CA
# 156                   Juniper Networks\r\n3.8            Cupertino, CA
# 160                          Health IQ\r\n3.9               Dallas, TX
# 163                           Sunovion\r\n3.5          Marlborough, MA
# 164     National Student Clearinghouse\r\n2.9              Herndon, VA
# 168                           Autodesk\r\n4.0        San Francisco, CA
# 172             Takeda Pharmaceuticals\r\n3.7            San Diego, CA
# 173             Dodge Data & Analytics\r\n2.8             Hamilton, NJ
# 174             Takeda Pharmaceuticals\r\n3.7               Boston, MA
# 175            Plymouth Rock Assurance\r\n3.3           Woodbridge, NJ
# 176                         CA-One Tech Cloud        San Francisco, CA
# 178             Takeda Pharmaceuticals\r\n3.7               Boston, MA
# 179                      Argo Group US\r\n3.4             New York, NY
# 183                            Zest AI\r\n3.9              Burbank, CA
# 185        The Hanover Insurance Group\r\n3.7            Worcester, MA
# 187                        Tempus Labs\r\n3.0              Chicago, IL
# 188          Recursion Pharmaceuticals\r\n4.7       Salt Lake City, UT
# 190          Rochester Regional Health\r\n3.3            Rochester, NY
# 192                Rubius Therapeutics\r\n4.4            Cambridge, MA
# 194          Rochester Regional Health\r\n3.3            Rochester, NY
# 195                      Credit Sesame\r\n4.1        Mountain View, CA
# 199     Software Engineering Institute\r\n2.6           Pittsburgh, PA
# 201  Pilot Flying J Travel Centers LLC\r\n3.0            Knoxville, TN
# 205              Echo Global Logistics\r\n3.4              Chicago, IL
# 208                   Acuity Insurance\r\n4.8            Sheboygan, WI
# 212                            KnowBe4\r\n4.8           Clearwater, FL
#
#                 Headquarters                     Size  Founded  \
# 21         Mountain View, CA     201 to 500 employees     2013
# 38        Gottingen, Germany  5001 to 10000 employees     1870
# 44               Chicago, IL   1001 to 5000 employees     1993
# 46           Foster City, CA         10000+ employees     1958
# 60            Cincinnati, OH     201 to 500 employees     1885
# 62             Palo Alto, CA    501 to 1000 employees     2006
# 73                Reston, VA    501 to 1000 employees     2010
# 75             Palo Alto, CA         10000+ employees     1939
# 81            Harrisburg, PA     201 to 500 employees     1997
# 91         San Francisco, CA     201 to 500 employees     1990
# 99         Silver Spring, MD        1 to 50 employees     2007
# 103           Washington, DC   1001 to 5000 employees     1935
# 105              Detroit, MI         10000+ employees     1994
# 107              Phoenix, AZ     201 to 500 employees     2010
# 119            Fort Mill, SC   1001 to 5000 employees     2000
# 128          Foster City, CA         10000+ employees     1958
# 130              Mc Lean, VA    501 to 1000 employees     2012
# 140               Denver, CO     201 to 500 employees     2011
# 143           Pittsburgh, PA    501 to 1000 employees     1984
# 147           Cincinnati, OH     201 to 500 employees     1987
# 149             Richland, WA   1001 to 5000 employees     1965
# 150           Clearwater, FL    501 to 1000 employees     2010
# 151         Indianapolis, IN      51 to 200 employees     2008
# 154          Springfield, MA  5001 to 10000 employees     1851
# 155  South San Francisco, CA         10000+ employees     1976
# 156            Sunnyvale, CA  5001 to 10000 employees     1996
# 160        Mountain View, CA     201 to 500 employees     2013
# 163          Marlborough, MA   1001 to 5000 employees     2010
# 164              Herndon, VA     201 to 500 employees     1993
# 168           San Rafael, CA  5001 to 10000 employees     1982
# 172             OSAKA, Japan         10000+ employees     1781
# 173             Hamilton, NJ     201 to 500 employees     2014
# 174             OSAKA, Japan         10000+ employees     1781
# 175               Boston, MA   1001 to 5000 employees     1982
# 176              Fremont, CA      51 to 200 employees     2017
# 178             OSAKA, Japan         10000+ employees     1781
# 179        Hamilton, Bermuda   1001 to 5000 employees     1948
# 183              Burbank, CA      51 to 200 employees     2009
# 185            Worcester, MA  5001 to 10000 employees     1852
# 187              Chicago, IL    501 to 1000 employees     2015
# 188       Salt Lake City, UT      51 to 200 employees     2013
# 190            Rochester, NY         10000+ employees     2014
# 192            Cambridge, MA     201 to 500 employees     2013
# 194            Rochester, NY         10000+ employees     2014
# 195        Mountain View, CA      51 to 200 employees     2010
# 199           Pittsburgh, PA    501 to 1000 employees     1984
# 201            Knoxville, TN         10000+ employees     1958
# 205              Chicago, IL   1001 to 5000 employees     2005
# 208            Sheboygan, WI   1001 to 5000 employees     1925
# 212           Clearwater, FL    501 to 1000 employees     2010
#
#                   Type of ownership  ... job_state same_state  age python_yn  \
# 21                Company - Private  ...        TX          0    9         0
# 38                 Company - Public  ...        CA          0  152         1
# 44                 Company - Public  ...        IL          1   29         1
# 46                 Company - Public  ...        WA          0   64         1
# 60   Subsidiary or Business Segment  ...        OH          1  137         1
# 62                 Company - Public  ...        CA          1   16         0
# 73                Company - Private  ...        VA          0   12         1
# 75                 Company - Public  ...        WA          0   83         0
# 81                Company - Private  ...        PA          1   25         0
# 91                 Company - Public  ...        CA          1   32         0
# 99                Company - Private  ...        MD          1   15         1
# 103               Company - Private  ...        DC          1   87         1
# 105                Company - Public  ...        MI          0   28         1
# 107               Company - Private  ...        AZ          1   12         0
# 119               Company - Private  ...        NC          0   22         0
# 128                Company - Public  ...        VA          0   64         1
# 130               Company - Private  ...        VA          0   10         1
# 140               Company - Private  ...        CO          1   11         1
# 143            College / University  ...        PA          1   38         1
# 147               Company - Private  ...        OH          1   35         1
# 149                      Government  ...        WA          1   57         0
# 150               Company - Private  ...        FL          1   12         1
# 151               Company - Private  ...        IN          1   14         1
# 154               Company - Private  ...        MA          0  171         1
# 155  Subsidiary or Business Segment  ...        CA          1   46         1
# 156                Company - Public  ...        CA          0   26         1
# 160               Company - Private  ...        TX          0    9         0
# 163               Company - Private  ...        MA          1   12         1
# 164          Nonprofit Organization  ...        VA          1   29         1
# 168                Company - Public  ...        CA          0   40         1
# 172                Company - Public  ...        CA          0  241         0
# 173               Company - Private  ...        NJ          1    8         1
# 174                Company - Public  ...        MA          0  241         0
# 175               Company - Private  ...        NJ          0   40         0
# 176               Company - Private  ...        CA          0    5         1
# 178                Company - Public  ...        MA          0  241         0
# 179                Company - Public  ...        NY          0   74         1
# 183               Company - Private  ...        CA          1   13         1
# 185                Company - Public  ...        MA          1  170         1
# 187               Company - Private  ...        IL          1    7         1
# 188               Company - Private  ...        UT          1    9         1
# 190                        Hospital  ...        NY          1    8         0
# 192                Company - Public  ...        MA          1    9         0
# 194                        Hospital  ...        NY          1    8         0
# 195               Company - Private  ...        CA          1   12         1
# 199            College / University  ...        PA          1   38         0
# 201               Company - Private  ...        TN          1   64         1
# 205                Company - Public  ...        IL          1   17         0
# 208               Company - Private  ...        WI          1   97         0
# 212               Company - Private  ...        FL          1   12         1
#
#      R_yn  spark  aws  excel        job_simp seniority
# 21      0      0    0      1  data scientist    senior
# 38      0      0    0      1  data scientist    senior
# 44      0      1    0      1  data scientist    senior
# 46      0      0    0      1  data scientist    senior
# 60      0      0    1      0  data scientist    senior
# 62      0      0    0      0  data scientist    senior
# 73      0      1    0      0  data scientist    senior
# 75      0      1    1      0  data scientist    senior
# 81      0      0    0      1         analyst        jr
# 91      0      0    0      1              na    senior
# 99      0      0    0      0  data scientist    senior
# 103     0      0    0      1  data scientist    senior
# 105     0      1    1      1  data scientist    senior
# 107     0      0    0      1         analyst    senior
# 119     0      1    1      0   data engineer    senior
# 128     0      1    0      0  data scientist    senior
# 130     0      0    1      0  data scientist    senior
# 140     0      0    0      0  data scientist    senior
# 143     0      0    0      1              na    senior
# 147     0      0    0      1  data scientist    senior
# 149     0      0    0      0  data scientist    senior
# 150     0      0    0      1         analyst    senior
# 151     0      1    1      0              na    senior
# 154     0      1    1      0  data scientist    senior
# 155     0      1    0      1  data scientist    senior
# 156     0      1    1      1  data scientist    senior
# 160     0      0    0      1  data scientist    senior
# 163     0      0    0      1              na    senior
# 164     0      0    0      1         analyst    senior
# 168     0      1    0      0  data scientist    senior
# 172     0      0    0      1              na    senior
# 173     0      0    0      1         analyst    senior
# 174     0      0    0      1              na    senior
# 175     0      0    0      1  data scientist    senior
# 176     0      0    1      1  data scientist    senior
# 178     0      0    0      0              na    senior
# 179     0      1    1      0  data scientist    senior
# 183     0      0    0      0  data scientist    senior
# 185     0      0    0      1  data scientist    senior
# 187     0      0    1      0             mle    senior
# 188     0      0    1      0  data scientist    senior
# 190     0      0    0      0              na    senior
# 192     0      0    0      0              na    senior
# 194     0      0    0      0              na    senior
# 195     0      1    1      0   data engineer    senior
# 199     0      0    0      0             mle    senior
# 201     0      0    0      0   data engineer    senior
# 205     0      0    0      0   data engineer    senior
# 208     0      0    0      0  data scientist    senior
# 212     0      0    0      1         analyst    senior
#
# [50 rows x 30 columns]

# %%
# Fix state Los Angeles
df.job_state.value_counts()
# Out:
#  CA             151
#  MA             103
#  NY              72
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  WA              21
#  NC              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  DC              11
#  CO              11
#  WI              10
#  IN              10
#  UT              10
#  AZ               9
#  MO               9
#  AL               8
#  GA               6
#  KY               6
#  DE               6
#  MI               6
#  CT               5
#  IA               5
#  LA               4
#  OR               4
#  NE               4
#  NM               3
#  KS               3
#  ID               2
#  MN               2
#  Los Angeles      1
#  RI               1
#  SC               1
# Name: job_state, dtype: int64

# %%
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')

# %%
df.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: job_state, dtype: int64

# %%
#df.drop('job state', inplace = True, axis = 1)

# %%
# Job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2555
# 1      4828
# 2      3495
# 3      3926
# 4      2748
#        ...
# 737    6219
# 738    6167
# 739    3107
# 740    1678
# 741    3710
# Name: desc_len, Length: 742, dtype: int64

# %%
# Competitor count
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
df[['num_comp','Competitors']]
# Out:
#      num_comp                                        Competitors
# 0           0                                                 -1
# 1           0                                                 -1
# 2           0                                                 -1
# 3           3  Oak Ridge National Laboratory, National Renewa...
# 4           3               Commerce Signals, Cardlytics, Yodlee
# ..        ...                                                ...
# 737         3                         Pfizer, AstraZeneca, Merck
# 738         3                    See Tickets, TicketWeb, Vendini
# 739         0                                                 -1
# 740         0                                                 -1
# 741         0                                                 -1
#
# [742 rows x 2 columns]

# %%
# Hourly wage to annual
df['min_salary'] = df.apply(lambda x: x.min_salary * 2000/1000 if x.hourly == 1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary * 2000/1000 if x.hourly == 1 else x.max_salary, axis = 1)

# %%
df[df.hourly == 1][['min_salary','max_salary','hourly']]
# Out:
#      min_salary  max_salary  hourly
# 165        34.0        48.0       1
# 177        42.0        68.0       1
# 197        36.0        50.0       1
# 202        42.0        68.0       1
# 210        30.0        50.0       1
# 246        34.0        48.0       1
# 271        42.0        68.0       1
# 337        36.0        50.0       1
# 345        48.0        78.0       1
# 357        42.0        68.0       1
# 363        50.0        56.0       1
# 408        42.0        58.0       1
# 409        20.0        34.0       1
# 492        36.0        50.0       1
# 509        48.0        78.0       1
# 533        42.0        68.0       1
# 542        50.0        56.0       1
# 617        42.0        58.0       1
# 618        20.0        34.0       1
# 645        54.0        94.0       1
# 666        36.0        50.0       1
# 682        48.0        78.0       1
# 711        42.0        68.0       1
# 724        50.0        56.0       1

# %%
df.company_text
# Out:
# 0                          Tecolote Research\r\n
# 1      University of Maryland Medical System\r\n
# 2                                    KnowBe4\r\n
# 3                                       PNNL\r\n
# 4                         Affinity Solutions\r\n
#                          ...
# 737                                      GSK\r\n
# 738                               Eventbrite\r\n
# 739           Software Engineering Institute\r\n
# 740                             Numeric, LLC\r\n
# 741             Riverside Research Institute\r\n
# Name: company_text, Length: 742, dtype: object

# %%
# removing "\r" and "\n" company_text
df['company_text'] = df.company_text.apply(lambda x: x.replace('\r','').replace('\n',''))

# %%
df['company_text']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_text, Length: 742, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   48.456873    0.528302    0.002695
# std     45.220324   38.855948    0.496965   53.900445    0.499535    0.051882
# min     16.000000   13.500000    0.000000   -1.000000    0.000000    0.000000
# 25%     96.000000   73.500000    0.000000   13.000000    0.000000    0.000000
# 50%    124.000000   97.500000    1.000000   26.000000    1.000000    0.000000
# 75%    155.000000  122.500000    1.000000   61.000000    1.000000    0.000000
# max    306.000000  254.000000    1.000000  278.000000    1.000000    1.000000
#
#             spark         aws       excel      desc_len    num_comp
# count  742.000000  742.000000  742.000000    742.000000  742.000000
# mean     0.225067    0.237197    0.522911   3910.172507    1.053908
# std      0.417908    0.425651    0.499812   1533.827777    1.384239
# min      0.000000    0.000000    0.000000    407.000000    0.000000
# 25%      0.000000    0.000000    0.000000   2834.000000    0.000000
# 50%      0.000000    0.000000    1.000000   3781.500000    0.000000
# 75%      0.000000    0.000000    1.000000   4772.000000    3.000000
# max      1.000000    1.000000    1.000000  10146.000000    4.000000

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['age','avg_salary','Rating'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Rating')
# Out:
# <AxesSubplot:>

# %%
df[['age','avg_salary','Rating','desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.019492  0.024665  0.165628
# avg_salary  0.019492    1.000000  0.013492  0.078093
# Rating      0.024665    0.013492  1.000000 -0.012631
# desc_len    0.165628    0.078093 -0.012631  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap = True)
sns.heatmap(df[['age','avg_salary','Rating','desc_len','num_comp']].corr(), vmax = .3, center = 0, cmap = cmap,
            square = True, linewidths = .5, cbar_kws = {"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_text', 'job_state','same_state', 'python_yn', 'R_yn',
       'spark', 'aws', 'excel', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print('graph for %s: total = %d' % (i, len(cat_num)))
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 30)
    plt.show()
# Out:
# graph for Location: total = 200
# graph for Headquarters: total = 198
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 60
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for company_text: total = 343
# graph for job_state: total = 37
# graph for same_state: total = 2
# graph for python_yn: total = 2
# graph for R_yn: total = 2
# graph for spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for job_simp: total = 7
# graph for seniority: total = 3

# %%
for i in df_cat[['Location','Headquarters','company_text']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_text: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          65.857843
# data engineer   105.403361
# data scientist  117.564516
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               84.853261

# %%
pd.pivot_table(df, index = ['job_simp','seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        jr          56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist jr         106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
pd.pivot_table(df, index = ['job_state','job_simp'], values = 'avg_salary').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_simp
# WI        na               54.000000
#           data scientist  113.500000
#           analyst          58.833333
# WA        na               97.500000
#           data scientist   99.764706
# ...                              ...
# AZ        analyst          55.000000
#           na              124.500000
# AL        na               43.750000
#           data engineer    65.000000
#           analyst          62.200000
#
# [114 rows x 1 columns]

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['job_state','job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_simp
# WI        na                       4
#           data scientist           3
#           analyst                  3
# WA        na                       1
#           data scientist          17
#           analyst                  3
# VA        na                       5
#           mle                      2
#           data scientist          18
#           data engineer           10
#           analyst                  6
# UT        data engineer            3
#           analyst                  4
#           data scientist           3
# TX        na                       7
#           data scientist          13
#           data engineer            8
# TN        data scientist           1
#           data engineer           10
#           analyst                  2
# SC        na                       1
# RI        analyst                  1
# PA        manager                  3
#           data engineer            1
#           data scientist           6
#           analyst                  8
#           mle                      7
#           na                       8
# OR        data scientist           3
#           data engineer            1
# OH        na                       3
#           data scientist           7
#           analyst                  4
# NY        na                      12
#           mle                      2
#           data scientist          40
#           data engineer            4
#           analyst                 14
# NM        data scientist           3
# NJ        data scientist           4
#           analyst                  6
#           data engineer            2
#           manager                  2
#           director                 2
#           na                       1
# NE        na                       4
# NC        na                      12
#           data scientist           3
#           data engineer            6
# MO        na                       3
#           manager                  1
#           data scientist           3
#           analyst                  2
# MN        data engineer            1
#           analyst                  1
# MI        manager                  2
#           data scientist           4
# MD        na                      16
#           data scientist          13
#           data engineer            3
#           analyst                  3
# MA        na                      46
#           manager                  5
#           director                 6
#           data scientist          30
#           data engineer           12
#           analyst                  4
# LA        analyst                  1
#           data engineer            2
#           na                       1
# KY        na                       4
#           data scientist           2
# KS        mle                      3
# IN        na                       4
#           data scientist           2
#           data engineer            4
# IL        analyst                  3
#           na                       6
#           mle                      2
#           director                 6
#           data scientist          15
#           data engineer            8
# ID        analyst                  2
# IA        analyst                  2
#           data engineer            3
# GA        data scientist           3
#           na                       3
# FL        data scientist           7
#           data engineer            3
#           analyst                  6
# DE        na                       6
# DC        data scientist           5
#           data engineer            4
#           analyst                  2
# CT        na                       3
#           data scientist           2
# CO        mle                      1
#           data engineer            3
#           analyst                  1
#           na                       3
#           data scientist           3
# CA        na                      27
#           mle                      5
#           manager                  9
#           data scientist          68
#           data engineer           25
#           analyst                 18
# AZ        data scientist           1
#           data engineer            5
#           analyst                  1
#           na                       2
# AL        na                       2
#           data engineer            1
#           analyst                  5

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
# DC         149.000000
# CA         142.522059
# UT         140.500000
# MO         127.666667
# IL         117.233333
# NC         117.000000
# NY         115.250000
# MA         113.750000
# WI         113.500000
# PA         113.333333
# MD         109.115385
# CO         108.666667
# VA         108.416667
# NJ         106.875000
# MI         106.625000
# OH         105.285714
# TX         100.730769
# WA          99.764706
# OR          98.500000
# FL          97.357143
# TN          96.000000
# IN          84.500000
# KY          84.000000
# CT          84.000000
# GA          81.333333
# NM          74.333333
# AZ          69.500000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
# rating, industry, sector, revenue, number of comp, hourly, employer provided, python, r, spark, aws, excel, desc_len, 
# Type of onwership

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'employer_provided', 'python_yn', 
                'R_yn', 'spark', 'aws', 'excel', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    if i != 'avg_salary':
        print(i)
        print(pd.pivot_table(df_pivots, index = i, values = 'avg_salary').sort_values(by = 'avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Industry
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# Telecommunications Services               131.500000
# Brokerage Services                        129.000000
# Auctions & Galleries                      128.000000
# Internet                                  123.810345
# Investment Banking & Asset Management     118.400000
# TV Broadcast & Cable Networks             117.750000
# Enterprise Software & Network Solutions   115.369048
# Computer Hardware & Software              115.194915
# -1                                        114.650000
# Accounting                                113.500000
# Biotech & Pharmaceuticals                 111.767857
# Insurance Agencies & Brokerages           109.250000
# K-12 Education                            108.875000
# Consulting                                108.689655
# Transportation Management                 107.500000
# Metals Brokers                            107.000000
# Staffing & Outsourcing                    106.200000
# Video Games                               106.166667
# Insurance Carriers                        105.626984
# Real Estate                               104.750000
# Transportation Equipment Manufacturing    104.500000
# Advertising & Marketing                   104.300000
# Wholesale                                 103.166667
# IT Services                               102.840000
# Colleges & Universities                   102.687500
# Aerospace & Defense                        99.060000
# Logistics & Supply Chain                   98.250000
# Gas Stations                               98.000000
# Mining                                     98.000000
# Consumer Products Manufacturing            95.350000
# Security Services                          93.500000
# Department, Clothing, & Shoe Stores        92.666667
# Stock Exchanges                            87.000000
# Industrial Manufacturing                   86.750000
# Consumer Product Rental                    86.666667
# Beauty & Personal Accessories Stores       85.500000
# Sporting Goods Stores                      85.000000
# Lending                                    83.000000
# Farm Support Services                      80.500000
# Energy                                     80.464286
# Education Training Services                79.500000
# Trucking                                   79.000000
# Religious Organizations                    78.833333
# Federal Agencies                           78.545455
# Research & Development                     78.394737
# Financial Transaction Processing           76.500000
# Health Care Products Manufacturing         73.000000
# Banks & Credit Unions                      70.625000
# Travel Agencies                            69.500000
# Health Care Services & Hospitals           67.622449
# Food & Beverage Manufacturing              53.250000
# Architectural & Engineering Services       50.500000
# Gambling                                   48.500000
# Social Assistance                          48.166667
# Telecommunications Manufacturing           44.000000
# Construction                               26.500000
# Sector
#                                     avg_salary
# Sector
# Media                               116.666667
# -1                                  114.650000
# Accounting & Legal                  113.500000
# Information Technology              113.191667
# Biotech & Pharmaceuticals           111.767857
# Insurance                           105.942029
# Real Estate                         104.750000
# Mining & Metals                     104.000000
# Telecommunications                  102.333333
# Education                           100.739130
# Consumer Services                    99.875000
# Retail                               99.666667
# Transportation & Logistics           99.312500
# Aerospace & Defense                  99.060000
# Business Services                    97.701031
# Finance                              97.369048
# Manufacturing                        84.044118
# Agriculture & Forestry               80.500000
# Oil, Gas, Energy & Utilities         80.464286
# Government                           78.545455
# Travel & Tourism                     69.500000
# Non-Profit                           68.611111
# Health Care                          67.622449
# Arts, Entertainment & Recreation     48.500000
# Construction, Repair & Maintenance   26.500000
# Revenue
#                                   avg_salary
# Revenue
# $5 to $10 million (USD)           126.111111
# $1 to $5 million (USD)            119.312500
# -1                                117.500000
# $10+ billion (USD)                115.165323
# Less than $1 million (USD)        108.625000
# $1 to $2 billion (USD)            104.533333
# Unknown / Non-Applicable          104.310345
# $50 to $100 million (USD)         100.565217
# $10 to $25 million (USD)          100.359375
# $2 to $5 billion (USD)             94.730769
# $5 to $10 billion (USD)            94.184211
# $500 million to $1 billion (USD)   86.991228
# $100 to $500 million (USD)         83.153846
# $25 to $50 million (USD)           82.837500
# num_comp
#           avg_salary
# num_comp
# 2         106.865854
# 1         106.208333
# 3         105.504386
# 0          97.602174
# 4          56.500000
# hourly
#         avg_salary
# hourly
# 0         103.1539
# 1          25.0000
# employer_provided
#                    avg_salary
# employer_provided
# 1                  119.970588
# 0                  100.172414
# python_yn
#            avg_salary
# python_yn
# 1          112.653061
# 0           87.155714
# R_yn
#       avg_salary
# R_yn
# 0     100.706757
# 1      70.750000
# spark
#        avg_salary
# spark
# 1      113.347305
# 0       96.931304
# aws
#      avg_salary
# aws
# 1    112.559659
# 0     96.915194
# excel
#        avg_salary
# excel
# 0      102.953390
# 1       98.502577
# Type of ownership
#                                 avg_salary
# Type of ownership
# -1                              117.500000
# Company - Public                110.893782
# Subsidiary or Business Segment  110.573529
# College / University            107.615385
# Company - Private               101.776829
# Government                       84.300000
# School / School District         77.750000
# Other Organization               77.500000
# Nonprofit Organization           68.281818
# Hospital                         54.000000
# Unknown                          39.500000

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
import os
os.path
# Out:
# <module 'ntpath' from 'C:\\ProgramData\\Anaconda3\\lib\\ntpath.py'>

# %%
#!pip install https://github.com/sulunemre/word_cloud/releases/download/2/wordcloud-0.post1+gd8241b5-cp310-cp310-win_amd64.whl

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import warnings
warnings.filterwarnings('ignore')

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc = WordCloud(background_color = "white", random_state=1, stopwords = STOPWORDS, max_words = 2000, width = 800, height = 1500)
wc.generate(text)

plt.figure(figsize = [10,10])
plt.imshow(wc, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
# --- END OF EDA ---
